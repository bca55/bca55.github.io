# %% [markdown]
# ---
# title: A Brief Look at Spotify
# author: Bryan Armpriest
# date: 2025-03-02
# categories: [python, pandas, music]
# image: "spotify.png"
# toc: true
# ---

# %%
#Let's load up some data from Spotify so that we can take a look at it!

import pandas as pd

spotify = pd.read_csv('https://bcdanl.github.io/data/spotify_all.csv')

# %%
spotify.info()
spotify
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198005 entries, 0 to 198004
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   pid            198005 non-null  int64
#  1   playlist_name  198005 non-null  object
#  2   pos            198005 non-null  int64
#  3   artist_name    198005 non-null  object
#  4   track_name     198005 non-null  object
#  5   duration_ms    198005 non-null  int64
#  6   album_name     198005 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 10.6+ MB
#            pid playlist_name  pos        artist_name  \
# 0            0    Throwbacks    0      Missy Elliott
# 1            0    Throwbacks    1     Britney Spears
# 2            0    Throwbacks    2            Beyoncé
# 3            0    Throwbacks    3  Justin Timberlake
# 4            0    Throwbacks    4             Shaggy
# ...        ...           ...  ...                ...
# 198000  999998            ✝️    6       Chris Tomlin
# 198001  999998            ✝️    7       Chris Tomlin
# 198002  999998            ✝️    8            Crowder
# 198003  999998            ✝️    9       Chris Tomlin
# 198004  999998            ✝️   10   Caleb and Kelsey
#
#                                         track_name  duration_ms  \
# 0       Lose Control (feat. Ciara & Fat Man Scoop)       226863
# 1                                            Toxic       198800
# 2                                    Crazy In Love       235933
# 3                                   Rock Your Body       267266
# 4                                     It Wasn't Me       227600
# ...                                            ...          ...
# 198000                                   Waterfall       209573
# 198001                                    The Roar       220106
# 198002        Lift Your Head Weary Sinner (Chains)       224666
# 198003                                We Fall Down       280960
# 198004      10,000 Reasons / What a Beautiful Name       178189
#
#                                             album_name
# 0                                         The Cookbook
# 1                                          In The Zone
# 2         Dangerously In Love (Alben für die Ewigkeit)
# 3                                            Justified
# 4                                             Hot Shot
# ...                                                ...
# 198000                                    Love Ran Red
# 198001                                    Love Ran Red
# 198002                                    Neon Steeple
# 198003  How Great Is Our God: The Essential Collection
# 198004          10,000 Reasons / What a Beautiful Name
#
# [198005 rows x 7 columns]
# Warning: total number of rows (198005) exceeds max_rows (20000). Limiting to first (20000) rows.

# %% [markdown]
# To start, I want to see if my favorite band is included in this DataFrame. I will do this two different ways, first by indexing (and searching) and then by using filtering methods. Both of the following code chunks provide the same filtered dataframe.

# %%
#Indexing, first we must set the index of the DataFrame to a new variable
spotify_name = spotify.set_index(['artist_name'])

#Now we just have to search for Coldplay!
spotify_name.loc[['Coldplay']]
# Out:
#                 pid playlist_name  pos                         track_name  \
# artist_name
# Coldplay         31   Running 2.0   88  Hymn For The Weekend - Seeb Remix
# Coldplay         45         angst   43                      The Scientist
# Coldplay         51         Kevin   27                           Midnight
# Coldplay         85           Gym    1            Adventure Of A Lifetime
# Coldplay         85           Gym    2               Hymn For The Weekend
# ...             ...           ...  ...                                ...
# Coldplay     999968   chill songs   89                A Sky Full of Stars
# Coldplay     999968   chill songs   90                       See You Soon
# Coldplay     999979   summer 2017   18                           Paradise
# Coldplay     999984          Lake    9            Adventure Of A Lifetime
# Coldplay     999989        PARTAY   23  Hymn For The Weekend - Seeb Remix
#
#              duration_ms                          album_name
# artist_name
# Coldplay          212647  A Head Full Of Dreams Tour Edition
# Coldplay          309600         A Rush Of Blood To The Head
# Coldplay          294666                       Ghost Stories
# Coldplay          263786               A Head Full Of Dreams
# Coldplay          258826               A Head Full Of Dreams
# ...                  ...                                 ...
# Coldplay          268466                       Ghost Stories
# Coldplay          171373                       The Blue Room
# Coldplay          278719                         Mylo Xyloto
# Coldplay          263786               A Head Full Of Dreams
# Coldplay          212647  A Head Full Of Dreams Tour Edition
#
# [483 rows x 6 columns]

# %%
#Filtering -> use of a the query() method
coldplay = spotify.query("artist_name == 'Coldplay'")
coldplay
# Out:
#            pid playlist_name  pos artist_name  \
# 1732        31   Running 2.0   88    Coldplay
# 2755        45         angst   43    Coldplay
# 2973        51         Kevin   27    Coldplay
# 4859        85           Gym    1    Coldplay
# 4860        85           Gym    2    Coldplay
# ...        ...           ...  ...         ...
# 196152  999968   chill songs   89    Coldplay
# 196153  999968   chill songs   90    Coldplay
# 196787  999979   summer 2017   18    Coldplay
# 196980  999984          Lake    9    Coldplay
# 197493  999989        PARTAY   23    Coldplay
#
#                                track_name  duration_ms  \
# 1732    Hymn For The Weekend - Seeb Remix       212647
# 2755                        The Scientist       309600
# 2973                             Midnight       294666
# 4859              Adventure Of A Lifetime       263786
# 4860                 Hymn For The Weekend       258826
# ...                                   ...          ...
# 196152                A Sky Full of Stars       268466
# 196153                       See You Soon       171373
# 196787                           Paradise       278719
# 196980            Adventure Of A Lifetime       263786
# 197493  Hymn For The Weekend - Seeb Remix       212647
#
#                                 album_name
# 1732    A Head Full Of Dreams Tour Edition
# 2755           A Rush Of Blood To The Head
# 2973                         Ghost Stories
# 4859                 A Head Full Of Dreams
# 4860                 A Head Full Of Dreams
# ...                                    ...
# 196152                       Ghost Stories
# 196153                       The Blue Room
# 196787                         Mylo Xyloto
# 196980               A Head Full Of Dreams
# 197493  A Head Full Of Dreams Tour Edition
#
# [483 rows x 7 columns]

# %% [markdown]
# Now, I'm curious to see how many times Coldplay appears in this particular dataset that contains 1 million different playlists.
#
# I am also particularly interested in the number of unique track_names that appear within this DataFrame.

# %%
coldplay.shape[0] #there are 483 observations of Coldplay in this data!
# Out:
# 483

# %%
spotify.shape[0]
# Out:
# 198005

# %%
483/198005 #Coldplay shows up in less than 1% of playlists, I suppose there is a very specific mood of a playlist that calls for Coldplay.
# Out:
# 0.002439332340092422

# %%
coldplay['track_name'].nunique() #74 unique tracks
# Out:
# 74

# %% [markdown]
# I also thought it would be interesting to see the mean position in which coldplay songs are added to these playlists (especially in comparison to the average position for all observations in the dataframe).

# %%
coldplay['pos'].mean() #Around the 45th position!
# Out:
# 44.79710144927536

# %%
spotify['pos'].mean()
# Out:
# 54.39170728011919

# %% [markdown]
# Finally, let's look at the length of these songs.

# %%
spotify['duration_ms'].mean()
# Out:
# 234740.84469079063

# %%
coldplay['duration_ms'].mean() #coldplay songs seem to be longer! lets see if there are any in particular through sorting.
# Out:
# 268694.7039337474

# %%
coldplay.sort_values(['duration_ms'], ascending = False)
#With this information in the dataframe, they range from 465957ms to 136866ms
# Out:
#            pid       playlist_name  pos artist_name  \
# 122515    1827                 Now    0    Coldplay
# 59456      881                 EDC   31    Coldplay
# 41930      631               house   11    Coldplay
# 4861        85                 Gym    3    Coldplay
# 107839    1607              sleeps   29    Coldplay
# ...        ...                 ...  ...         ...
# 196153  999968         chill songs   90    Coldplay
# 135923  999023           Pop songs   41    Coldplay
# 59961      887           Reception   61    Coldplay
# 9437       144               picks   25    Coldplay
# 44608      665  recommendations !!   48    Coldplay
#
#                                                track_name  duration_ms  \
# 122515                                                  O       465957
# 59456   Every Teardrop Is a Waterfall - Coldplay vs. S...       408828
# 41930   Every Teardrop Is a Waterfall - Coldplay vs. S...       408828
# 4861                                                Up&Up       405320
# 107839                                            Gravity       380946
# ...                                                   ...          ...
# 196153                                       See You Soon       171373
# 135923                                Life In Technicolor       149133
# 59961                                 Life In Technicolor       149133
# 9437                                               U.F.O.       137819
# 44608                                         Don't Panic       136866
#
#                                        album_name
# 122515                              Ghost Stories
# 59456                                   Until Now
# 41930                                   Until Now
# 4861                        A Head Full Of Dreams
# 107839                                       Talk
# ...                                           ...
# 196153                              The Blue Room
# 135923  Viva La Vida Or Death And All His Friends
# 59961   Viva La Vida Or Death And All His Friends
# 9437                                  Mylo Xyloto
# 44608                                  Parachutes
#
# [483 rows x 7 columns]

# %% [markdown]
# Looking back at my very brief look at Coldplay observations within the Spotify DataFrame, I learned quite a bit from the data.
#
# 1.   Coldplay showed up in a fairly low number of playlists (less than 1%)
# 2.   There was quite a range in the length of the tracks, from 136 seconds to 465 seconds.
# 3.   When comparing the average position, Coldplay comes slightly sooner in playlists than the average for all songs.

# %% [markdown]
# # Second approach to the data: With Visualization using Seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Use pandas to identify the ten artists with the most tracks
sum_tracks_by_artist = spotify.groupby('artist_name').agg(sum_appearances = ('track_name', 'count')).reset_index()
top_10 = sum_tracks_by_artist.nlargest(10, 'sum_appearances', keep = 'all')
top_10_artists = top_10['artist_name'].tolist()
top_10_artists
#Now we just need to filter out the dataframe so it includes JUST those that are in this list of artists (top 10).
# Out:
# ['Drake',
#  'Kanye West',
#  'Kendrick Lamar',
#  'Rihanna',
#  'The Weeknd',
#  'Future',
#  'Eminem',
#  'Lil Uzi Vert',
#  'Ed Sheeran',
#  'The Chainsmokers']

# %% [markdown]
# Now, given the list of the top artists on Spotify, we can examine where they're placed in playlists (pos variable). We can visualize this using histogram plots, one that is distinct for every artist. All of these have the same count variable on the left, which is simply the number of occurences at a certain point in the playlist.
#
# The only thing is; I was unable to order them in the order in which they appeared to have the most tracks, it resorted back to their appearances in the dataframe when creating the histograms.

# %%
spotify_top_10 = spotify[spotify['artist_name'].isin(top_10_artists)]
spotify_top_10

(
 sns.FacetGrid(
       data = spotify_top_10,
       col = 'artist_name',
       hue = 'artist_name'
       )
 .map(sns.histplot, 'pos')
 )

# %% [markdown]
# *Keeping in mind the ACTUAL order of the artists:
# 'Drake', 'Kanye West', 'Kendrick Lamar', 'Rihanna', 'The Weeknd', 'Future', 'Eminem', 'Lil Uzi Vert', 'Ed Sheeran', 'The Chainsmokers'*
#
# Based on these histograms for each artist, there is always a right-skew to the distribution of positions in the playlist they're in. There appears to be a strong correlation between the start of a playlist and the inclusion of the music of these top 10 artists. This makes sense, since they are popular artists, with the top 10 most tracks appearing in playlists, and are more likely to be recognized and thought of toward the beginning of the creation of a playlist, or added early by an algorithm.

# %% [markdown]
# ### As always, thanks for reading!
